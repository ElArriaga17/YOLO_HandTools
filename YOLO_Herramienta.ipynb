# %% [markdown]
# <a href="https://colab.research.google.com/github/ElArriaga17/YOLO_HandTools/blob/main/YOLO_Herramienta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow ultralytics

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="T8gKamR6BnJs29VuMOXX")
project = rf.workspace("isaass-workspace").project("herramientas-de-mano")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
model = YOLO("yolo11s.pt")

# %%
data_path = "/workspaces/YOLO_HandTools/dataset/content/Herramientas-de-mano-1/data.yaml"
results = model.train(data=data_path,
                      epochs=15,
                      imgsz=640)
# Out:
# Ultralytics 8.4.72 🚀 Python-3.12.3 torch-2.12.1+cu130 CPU (AMD EPYC 7763 64-Core Processor)
# ...

# %%
# Cargamos el modelo ya entrenado
custom_model = YOLO("/content/runs/detect/train/weights/best.pt")

# Realizamos predicciones sobre algunas imágenes
res = custom_model("/content/Herramientas-de-mano-1/train/images")
# Out:
# image 1/73 /content/Herramientas-de-mano-1/train/images/IMG-20260619-WA0023_jpg.rf.6f9193961517d81c1b8a4d2b226c75e7.jpg: 640x640 5 Martillos, 1 Nivel, 1 PinzasPresion, 1 Rotomartillo, 15.6ms
# image 2/73 /content/Herramientas-de-mano-1/train/images/IMG-20260619-WA0026_jpg.rf.fbae5e52209bb2c01e7e0d24634f649a.jpg: 640x640 1 Martillo, 15.8ms
# image 3/73 /content/Herramientas-de-mano-1/train/images/IMG-20260619-WA0029_jpg.rf.7bd4f05c86f14a8439b1d2797f240155.jpg: 640x640 1 Martillo, 19.6ms
# image 4/73 /content/Herramientas-de-mano-1/train/images/IMG-20260619-WA0033_jpg.rf.0968ad23c875aa9487aa806b5acca233.jpg: 640x640 1 Martillo, 15.5ms
# image 5/73 /content/Herramientas-de-mano-1/train/images/IMG-20260619-WA0035_jpg.rf.9e3771890921f090fc72684bdf379386.jpg: 640x640 1 Martillo, 18.2ms
# image 6/73 /content/Herramientas-de-mano-1/train/images/IMG-20260619-WA0040_jpg.rf.57b1ee69cad6a10916afaa16649095e6.jpg: 640x640 1 Nivel, 15.5ms
# ...

# %%
# Visualizamos los resultados de las detecciones
res[32].show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>
